# %%
# !pip install transformers

# %%
# !pip install xformers

# %%
# !pip install gradio

# %%
import torch
import pandas as pd
import numpy as np
import gradio as gr
import matplotlib.pyplot as plt
from tqdm import tqdm

from transformers import pipeline
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig

# %% [markdown]
# # Labeling

# %%
df = pd.read_csv('/content/films_data_to_label.csv')
df.dropna(inplace=True)
df.head(3)
# Out:
#   movieID               genders  \
# 0      m0       ['m', 'f', 'm']
# 1      m0  ['f', 'm', 'f', 'm']
# 2      m0       ['f', 'f', 'f']
#
#                                                lines  \
# 0  ['Why?', 'Unsolved mystery.  She used to be re...
# 1  ['do you listen to this crap?', 'What crap?', ...
# 2  ["You're ruining my life'  Because you won't b...
#
#                                    char_names                 movie_title  \
# 0            ['CAMERON', 'BIANCA', 'CAMERON']  10 things i hate about you
# 1  ['BIANCA', 'CAMERON', 'BIANCA', 'CAMERON']  10 things i hate about you
# 2                 ['BIANCA', 'KAT', 'BIANCA']  10 things i hate about you
#
#                   genres  text_length
# 0  ['comedy', 'romance']          151
# 1  ['comedy', 'romance']          162
# 2  ['comedy', 'romance']          190

# %%
df.shape
# Out:
# (9517, 7)

# %%
df['lines'] = df['lines'].apply(lambda x: eval(x))

# %%
df['genres'] = df['genres'].apply(lambda x: eval(x))

# %%
df['char_names'] = df['char_names'].apply(lambda x: eval(x))

# %%
df['genders'] = df['genders'].apply(lambda x: eval(x))
df['genders'] = df['genders'].apply(lambda x: x if '?' not in x else np.nan)

# %%
df.dropna(inplace=True)

# %%
df['genders'] = df['genders'].apply(lambda x: ['Man' if i in ['m', 'M'] else 'Woman' for i in x])

# %%
df_to_label = df.sample(300, random_state=42)
df_to_label.reset_index(inplace=True, drop=True)

# %%
df_to_label.head(3)
# Out:
#   movieID                                        genders  \
# 0    m505                  [Man, Woman, Man, Woman, Man]
# 1    m426                  [Man, Woman, Man, Woman, Man]
# 2    m455  [Man, Man, Man, Man, Man, Man, Man, Man, Man]
#
#                                                lines  \
# 0  [And it's sexier in the dark., Dewey you and I...
# 1  [Plenty of time., What are these?, I don't kno...
# 2  ['You Will Anderson?, Who're you?, I'm Duff., ...
#
#                                           char_names        movie_title  \
# 0                  [DEWEY, GALE, DEWEY, GALE, DEWEY]           scream 2
# 1                  [PETER, MAYA, PETER, MAYA, PETER]         lost souls
# 2  [DUFF, WILL, DUFF, WILL, DUFF, WILL, DUFF, WIL...  nothing but a man
#
#                                genres  text_length
# 0         [horror, mystery, thriller]          176
# 1  [drama, horror, thriller, romance]          178
# 2                    [drama, romance]          192

# %%
# https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment-latest

MODEL = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.to('cuda:0')
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=3, bias=True)
#   )
# )

# %%
def convert_to_dataset_torch(data: str):
    input_ids = []
    attention_masks = []
    encoded_dict = tokenizer.encode_plus(data,
                                         max_length=256,
                                         padding='max_length',
                                         return_attention_mask=True,
                                         return_tensors='pt',
                                         truncation=True)

    input_ids.append(encoded_dict['input_ids'])
    attention_masks.append(encoded_dict['attention_mask'])
    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)
    input_ids.to(dtype=torch.long)
    attention_masks.to(dtype=torch.long)

    return input_ids, attention_masks

# %%
preds_all = []
for i in tqdm(df_to_label['lines']):
    preds_dial = []
    for k in i:
        converted = convert_to_dataset_torch(k)
        preds = model(input_ids=converted[0].to('cuda:0'),
                      attention_mask=converted[1].to('cuda:0')).logits
        predictions = torch.argmax(torch.nn.Softmax(dim=1)(preds), axis=1)
        preds_dial.append(predictions.item())
    preds_all.append(preds_dial)
# Out:
# 100%|██████████| 300/300 [00:42<00:00,  7.01it/s]

# %%
df_to_label['preds'] = pd.Series(preds_all)

# %%
df_labeled = df_to_label.drop(columns=['text_length'])

# %%
df_labeled.head(3)
# Out:
#   movieID                                        genders  \
# 0    m505                  [Man, Woman, Man, Woman, Man]
# 1    m426                  [Man, Woman, Man, Woman, Man]
# 2    m455  [Man, Man, Man, Man, Man, Man, Man, Man, Man]
#
#                                                lines  \
# 0  [And it's sexier in the dark., Dewey you and I...
# 1  [Plenty of time., What are these?, I don't kno...
# 2  ['You Will Anderson?, Who're you?, I'm Duff., ...
#
#                                           char_names        movie_title  \
# 0                  [DEWEY, GALE, DEWEY, GALE, DEWEY]           scream 2
# 1                  [PETER, MAYA, PETER, MAYA, PETER]         lost souls
# 2  [DUFF, WILL, DUFF, WILL, DUFF, WILL, DUFF, WIL...  nothing but a man
#
#                                genres                        preds
# 0         [horror, mystery, thriller]              [2, 0, 0, 0, 0]
# 1  [drama, horror, thriller, romance]              [1, 1, 1, 1, 1]
# 2                    [drama, romance]  [1, 1, 1, 1, 1, 1, 1, 1, 2]

# %%
labels = ['negative','neutral','positive']
mapping = {i: k for i, k in enumerate(labels)}
df_to_label['preds'] = df_to_label['preds'].apply(lambda x: [*map(mapping.get, x)])

# %%
df_to_label
# Out:
#     movieID                                        genders  \
# 0      m505                  [Man, Woman, Man, Woman, Man]
# 1      m426                  [Man, Woman, Man, Woman, Man]
# 2      m455  [Man, Man, Man, Man, Man, Man, Man, Man, Man]
# 3      m265                                 [Woman, Woman]
# 4      m565                [Woman, Man, Woman, Man, Woman]
# ..      ...                                            ...
# 295     m14                                     [Man, Man]
# 296    m441                                   [Woman, Man]
# 297      m2                                     [Man, Man]
# 298    m202                 [Man, Man, Man, Man, Man, Man]
# 299    m127                 [Man, Man, Man, Man, Man, Man]
#
#                                                  lines  \
# 0    [And it's sexier in the dark., Dewey you and I...
# 1    [Plenty of time., What are these?, I don't kno...
# 2    ['You Will Anderson?, Who're you?, I'm Duff., ...
# 3    [We can't.  We haven't left the house since th...
# 4    [Get back inside the town and see if the Engli...
# ..                                                 ...
# 295  [George uh... you're gonna break his little ch...
# 296  [Now don't fuss Paul., Why would I run away? I...
# 297  [So tabloids don't have to do re enactments.  ...
# 298  [I'm telling you baby you always double down o...
# 299  [So I'm like 'Maybe I'm not on the list cause ...
#
#                                             char_names        movie_title  \
# 0                    [DEWEY, GALE, DEWEY, GALE, DEWEY]           scream 2
# 1                    [PETER, MAYA, PETER, MAYA, PETER]         lost souls
# 2    [DUFF, WILL, DUFF, WILL, DUFF, WILL, DUFF, WIL...  nothing but a man
# 3                                     [BARBARA, LYDIA]       beetle juice
# 4               [JEANNE, AULON, JEANNE, AULON, JEANNE]      the messenger
# ..                                                 ...                ...
# 295                                    [SYKES, JETSON]       alien nation
# 296                                      [ANNIE, PAUL]             misery
# 297                                      [EMIL, EDDIE]         15 minutes
# 298            [TRENT, MIKE, TRENT, MIKE, TRENT, MIKE]           swingers
# 299         [RICKY, BOBBY, RICKY, BOBBY, RICKY, BOBBY]               made
#
#                                  genres  text_length  \
# 0           [horror, mystery, thriller]          176
# 1    [drama, horror, thriller, romance]          178
# 2                      [drama, romance]          192
# 3                     [comedy, fantasy]          154
# 4                 [drama, romance, war]          167
# ..                                  ...          ...
# 295    [crime, drama, sci-fi, thriller]          167
# 296                          [thriller]          157
# 297    [action, crime, drama, thriller]          152
# 298                     [comedy, drama]          189
# 299    [comedy, crime, drama, thriller]          182
#
#                                                  preds
# 0    [positive, negative, negative, negative, negat...
# 1        [neutral, neutral, neutral, neutral, neutral]
# 2    [neutral, neutral, neutral, neutral, neutral, ...
# 3                                 [negative, negative]
# 4      [neutral, negative, neutral, positive, neutral]
# ..                                                 ...
# 295                               [negative, negative]
# 296                                [neutral, positive]
# 297                                [neutral, negative]
# 298  [neutral, neutral, positive, neutral, positive...
# 299  [negative, negative, negative, neutral, negati...
#
# [300 rows x 8 columns]

# %%
df_to_label.to_csv('films_data_labeled.csv', index=False)

# %% [markdown]
# # Gradio visualization

# %%
df = pd.read_csv('/content/films_data_labeled.csv')

# %%
df
# Out:
#     movieID                                            genders  \
# 0      m505            ['Man', 'Woman', 'Man', 'Woman', 'Man']
# 1      m426            ['Man', 'Woman', 'Man', 'Woman', 'Man']
# 2      m455  ['Man', 'Man', 'Man', 'Man', 'Man', 'Man', 'Ma...
# 3      m265                                 ['Woman', 'Woman']
# 4      m565          ['Woman', 'Man', 'Woman', 'Man', 'Woman']
# ..      ...                                                ...
# 295     m14                                     ['Man', 'Man']
# 296    m441                                   ['Woman', 'Man']
# 297      m2                                     ['Man', 'Man']
# 298    m202         ['Man', 'Man', 'Man', 'Man', 'Man', 'Man']
# 299    m127         ['Man', 'Man', 'Man', 'Man', 'Man', 'Man']
#
#                                                  lines  \
# 0    ["And it's sexier in the dark.", 'Dewey you an...
# 1    ['Plenty of time.', 'What are these?', "I don'...
# 2    ["'You Will Anderson?", "Who're you?", "I'm Du...
# 3    ["We can't.  We haven't left the house since t...
# 4    ['Get back inside the town and see if the Engl...
# ..                                                 ...
# 295  ["George uh... you're gonna break his little c...
# 296  ["Now don't fuss Paul.", "Why would I run away...
# 297  ["So tabloids don't have to do re enactments. ...
# 298  ["I'm telling you baby you always double down ...
# 299  ["So I'm like 'Maybe I'm not on the list cause...
#
#                                             char_names        movie_title  \
# 0          ['DEWEY', 'GALE', 'DEWEY', 'GALE', 'DEWEY']           scream 2
# 1          ['PETER', 'MAYA', 'PETER', 'MAYA', 'PETER']         lost souls
# 2    ['DUFF', 'WILL', 'DUFF', 'WILL', 'DUFF', 'WILL...  nothing but a man
# 3                                 ['BARBARA', 'LYDIA']       beetle juice
# 4     ['JEANNE', 'AULON', 'JEANNE', 'AULON', 'JEANNE']      the messenger
# ..                                                 ...                ...
# 295                                ['SYKES', 'JETSON']       alien nation
# 296                                  ['ANNIE', 'PAUL']             misery
# 297                                  ['EMIL', 'EDDIE']         15 minutes
# 298  ['TRENT', 'MIKE', 'TRENT', 'MIKE', 'TRENT', 'M...           swingers
# 299  ['RICKY', 'BOBBY', 'RICKY', 'BOBBY', 'RICKY', ...               made
#
#                                          genres  text_length  \
# 0             ['horror', 'mystery', 'thriller']          176
# 1    ['drama', 'horror', 'thriller', 'romance']          178
# 2                          ['drama', 'romance']          192
# 3                         ['comedy', 'fantasy']          154
# 4                   ['drama', 'romance', 'war']          167
# ..                                          ...          ...
# 295    ['crime', 'drama', 'sci-fi', 'thriller']          167
# 296                                ['thriller']          157
# 297    ['action', 'crime', 'drama', 'thriller']          152
# 298                         ['comedy', 'drama']          189
# 299    ['comedy', 'crime', 'drama', 'thriller']          182
#
#                                                  preds
# 0    ['positive', 'negative', 'negative', 'negative...
# 1    ['neutral', 'neutral', 'neutral', 'neutral', '...
# 2    ['neutral', 'neutral', 'neutral', 'neutral', '...
# 3                             ['negative', 'negative']
# 4    ['neutral', 'negative', 'neutral', 'positive',...
# ..                                                 ...
# 295                           ['negative', 'negative']
# 296                            ['neutral', 'positive']
# 297                            ['neutral', 'negative']
# 298  ['neutral', 'neutral', 'positive', 'neutral', ...
# 299  ['negative', 'negative', 'negative', 'neutral'...
#
# [300 rows x 8 columns]

# %%
df['genders'] = df['genders'].apply(lambda x: eval(x))
df['lines'] = df['lines'].apply(lambda x: eval(x))
df['char_names'] = df['char_names'].apply(lambda x: eval(x))
df['genres'] = df['genres'].apply(lambda x: eval(x))
df['preds'] = df['preds'].apply(lambda x: eval(x))

# %%
all_genres = df.genres.explode().unique().tolist()

# %%
def get_stat_for_genre(genre):
    df['stat_genre'] = df['genres'].apply(lambda x: True if genre in x else False)
    df_final = df[df['stat_genre']]
    df_final = df_final.explode(['char_names', 'genders', 'preds'])
    df_final = df_final.groupby('genders')['preds'].value_counts(normalize=True)

    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    for ax, gender in zip(axes, df_final.index.get_level_values('genders').unique()):
        ax.pie(df_final[gender], labels=df_final[gender].index.tolist(), autopct='%1.1f%%', textprops={'color':"b"})
        ax.set_xlabel(gender, color='white')

    return fig

# %%
def statistics():
    gen = gr.Dropdown(all_genres, label='genre')
    return gr.Interface(
        fn=get_stat_for_genre,
        inputs=gen,
        outputs=gr.Plot(label='Statistics'),
        theme=gr.themes.Soft(),
    )

# %%
statistics().launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
